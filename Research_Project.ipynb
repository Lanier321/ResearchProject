# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanier321/ResearchProject/blob/main/Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn import datasets, model_selection
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from os import rename

url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/refs/heads/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
covid_df = pd.read_csv(url)

covid_df = covid_df.dropna()
covid_df = covid_df.drop(columns=['Province/State'])

Lat_DF = covid_df[covid_df['Country/Region'] == 'United Kingdom']
Lat_Denmark = covid_df[covid_df['Country/Region'] == 'Denmark']
Lat_France = covid_df[covid_df['Country/Region'] == 'France']
Lat_DFrance = covid_df[covid_df['Country/Region'] == 'United Kingdom']


Removed_na = covid_df.dropna()

 # [Removed_na['Country/Region'] == 'Australia']

model = LinearRegression()
Removed_na = Removed_na.groupby('Country/Region').sum()
Removed_na = Removed_na.drop(['China','New Zealand','Australia','Netherlands','Canada'])
Removed_na.reset_index()
#'Lat','Long'
#Removed_na.drop(['United Kingdom','France','Denmark'])
#renamed_variables = ['']
#'1/22/20',     '1/23/20',      '1/24/20',      '1/25/20',      '1/26/20',      '1/27/20', '1/28/20',   '1/29/20','2/28/23',    '3/1/23',       '3/2/23',       '3/3/23',       '3/4/23',       '3/5/23',       '3/6/23',       '3/7/23','3/8/23'



#Removed_na = Removed_na.drop(columns=['1/30/20',       '1/31/20',      '2/1/20',       '2/2/20',       '2/3/20',       '2/4/20',       '2/5/20',       '2/6/20','1/22/20', '1/23/20',  '1/24/20',      '1/25/20',      '1/26/20',      '1/27/20',      '1/28/20',      '1/29/20',      '2/28/23',      '3/1/23',       '3/2/23',       '3/3/23',       '3/4/23',       '3/5/23',       '3/6/23',       '3/7/23',       '3/8/23', '2/7/20',     '2/8/20',       '2/9/20',       '2/10/20',      '2/11/20',      '2/12/20',      '2/13/20',      '2/14/20','2/15/20',    '2/16/20',      '2/17/20',      '2/18/20',      '2/19/20',      '2/20/20',      '2/21/20',      '2/22/20','2/23/20',    '2/24/20',      '2/25/20',      '2/26/20',      '2/27/20',      '2/28/20',      '2/29/20'],axis=1)
#'3/2/23',      '3/3/23',       '3/4/23',       '3/5/23',       '3/6/23',       '3/7/23',       '3/8/23', '2/27/23'
# Drop columns 'Lat' and 'Long' from the result

y = Removed_na['Lat']

x = Removed_na[['3/9/23', '3/2/23',     '3/3/23',       '3/4/23',       '3/5/23',       '3/6/23',       '3/7/23',       '3/8/23']]


# Transpose y to plot the time series
# Select the dates to plot
dates_to_plot = ['3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23', '3/8/23']
Lats_to_plot = ['3.93390','-17.67970','16.26500','14.64150','-12.827500','-20.904305','-21.115100']
# Select the death counts for these dates for Australia
Lat_DF.head(20)
# Out:
#      Country/Region        Lat        Long  1/22/20  1/23/20  1/24/20  \
# 264  United Kingdom  18.220600  -63.068600        0        0        0
# 265  United Kingdom  32.307800  -64.750500        0        0        0
# 266  United Kingdom  18.420700  -64.640000        0        0        0
# 267  United Kingdom  19.313300  -81.254600        0        0        0
# 268  United Kingdom  49.372300   -2.364400        0        0        0
# 269  United Kingdom -51.796300  -59.523600        0        0        0
# 270  United Kingdom  36.140800   -5.353600        0        0        0
# 271  United Kingdom  49.448196   -2.589490        0        0        0
# 272  United Kingdom  54.236100   -4.548100        0        0        0
# 273  United Kingdom  49.213800   -2.135800        0        0        0
# 274  United Kingdom  16.742498  -62.187366        0        0        0
# 275  United Kingdom -24.376800 -128.324200        0        0        0
# ...

# %%
x = Lat_DF[['Lat','Long']]
Y = Lat_DF[['3/8/23']]

X_train,X_test,y_train,y_test = train_test_split(x,Y,test_size=0.2,random_state=42)

model = LinearRegression()

model.fit(X_train,y_train)
pred = model.predict(X_test)


plt.figure(figsize=(10,6))

plt.plot(y_test,pred,alpha=0.5,color='blue')
plt.xlabel = 'Lat/Long'
plt.ylabel = 'Date'
plt.title('Lat/Long vs Date')
plt.grid()
plt.show()

# %%
dates_to_plot = ['3/8/23']

# Select the death counts for the specified dates from Lat_DF
uk_deaths = Lat_DF[dates_to_plot]
uk_latitudes = Lat_DF[['Long']]

# Sum the deaths across the selected dates for each location in the UK
uk_total_deaths = uk_deaths.sum(axis=1)

     #'3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23','

plt.figure(figsize=(10, 6)) # Adjust figure size for better readability
plt.scatter(uk_latitudes, uk_deaths,alpha=0.5,color='Blue')
plt.xlabel('Longitude')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths in United Kingdom by Longitude on Selected Dates')
plt.tight_layout()
plt.grid()
plt.show()

# %%
dates_to_plot = ['3/8/23']

# Select the death counts for the specified dates from Lat_DF
France_deaths = Lat_France[dates_to_plot]
France_Lat_Long = Lat_France[['Lat','Long']]

# Sum the deaths across the selected dates for each location in the UK

     #'3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23','

plt.figure(figsize=(10, 6)) # Adjust figure size for better readability
plt.plot(France_Lat_Long, France_deaths)
plt.xlabel('Latitude/Longitude')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths in Denmark by Latitude and Longitude on Selected Dates')
plt.tight_layout()
plt.grid()
plt.show()

# %%
dates_to_plot = ['3/8/23']

# Select the death counts for the specified dates from Lat_DF
uk_deaths = Lat_DF[dates_to_plot]
uk_lats = Lat_DF['Lat']

# Sum the deaths across the selected dates for each location in the UK
uk_total_deaths = uk_deaths.sum(axis=1)

     #'3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23','

plt.figure(figsize=(10, 6)) # Adjust figure size for better readability
plt.scatter(uk_lats, uk_deaths,alpha=0.5,color='blue')
plt.xlabel('Latitude')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths in United Kingdom by Longitude on Selected Dates')
plt.tight_layout()
plt.grid()
plt.show()

# %%
dates_to_plot = ['3/8/23']

# Select the death counts for the specified dates from Lat_DF
uk_deaths = Lat_DF[dates_to_plot]
uk_latitudes = Lat_DF[['Lat','Long']]

# Sum the deaths across the selected dates for each location in the UK
uk_total_deaths = uk_deaths.sum(axis=1)

     #'3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23','

plt.figure(figsize=(20, 6)) # Adjust figure size for better readability
plt.plot(uk_latitudes, uk_deaths)
plt.xlabel('Latitude/Longitude')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths in United Kingdom by Latitude on Selected Dates')
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()

# %%
dates_to_plot = ['3/8/23']

# Select the death counts for the specified dates from Lat_DF
Denmark_deaths = Lat_Denmark[dates_to_plot]
Denmark_Lat_Long = Lat_Denmark[['Lat','Long']]

# Sum the deaths across the selected dates for each location in the UK
Denmark_total_deaths = Denmark_deaths.sum(axis=1)

     #'3/9/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23', '3/7/23','

plt.figure(figsize=(10, 6)) # Adjust figure size for better readability
plt.plot(Denmark_Lat_Long, Denmark_deaths,alpha=0.9,color='blue')
plt.xlabel('Latitude/Longitude')
plt.ylabel('Total Deaths')
plt.title('Total COVID-19 Deaths in Denmark by Latitude and Longitude on Selected Dates')
plt.tight_layout()
plt.grid()
plt.show()
